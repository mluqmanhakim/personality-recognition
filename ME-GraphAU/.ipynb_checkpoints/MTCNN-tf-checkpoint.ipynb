# %%
from mtcnn import MTCNN
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os
import time
# Out:
# 2022-06-24 23:15:13.751723: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:15:13.751747: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
img_path = "/home/luqman/ME-GraphAU/data/DISFA/img/SN001/1.png"

# %%
def get_box_face(img_path):
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    detector = MTCNN()
    out = detector.detect_faces(img)
    return out[0]['box']

# crop image and resize to 224x224
def crop_img(img_path, coords, out_path):
    image_obj = Image.open(img_path)
    cropped_image = image_obj.crop(coords)
    img = cropped_image.resize((224,224))
    img.save(out_path)
    
# bbox has 4 elements, 1st and 2nd elements are top left x,y coordinates
# 3rd and 4th elements are width and length
def show_img(img_path, bbox):
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    cv_img = np.array(img)
    x1 = int(bbox[0])
    y1 = int(bbox[1])
    x2 = int(bbox[0]) + int(bbox[2])
    y2 = int(bbox[1]) + int(bbox[3])
    cv2.rectangle(cv_img, (x1, y1), (x2, y2), (0,255,0), 3)
    plt.imshow(cv_img)
    plt.show()
    
def rescale_box(box, scale):
    cx = box[0] + int(box[2]/2)
    cy = box[1] + int(box[3]/2)
    w_max = max(box[2], box[3])
    w = int(w_max * scale)
    x = cx - int(w/2)
    y = cy - int(w/2)
    box = [x,y,w,w]
    return box

# %%
box = get_box_face(img_path)
# Out:
# 2022-06-23 11:01:50.536603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-23 11:01:50.538487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-23 11:01:50.540282: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-23 11:01:50.541509: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-23 11:01:50.542509: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-23 11:01:50.558362: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-23 11:01:50.559266: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-23 11:01:50.560676: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-23 11:01:50.562931: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 80ms/step

# %%
show_img(img_path, box)

# %%
s_box = rescale_box(box, 1.4)

# %%
show_img(img_path, s_box)

# %%
coords = (s_box[0], s_box[1], s_box[0]+s_box[2], s_box[1]+s_box[3])
out_path = "/home/luqman/img.png"
crop_img(img_path, coords, out_path)

# %%
start_time = time.time()
input_dir = "/home/luqman/ME-GraphAU/data/DISFA/img"
video_names = ['SN009']

for v in video_names:
    boxes = []
    img_dir = os.path.join(input_dir, v)
    frame_count = len([frame for frame in os.listdir(img_dir)])
    
    for i in range(frame_count):
        filename = str(i+1) + '.png'
        img_path = os.path.join(img_dir, filename)
        box = get_box_face(img_path)
        boxes.append(box)
        break
            
    print(boxes)
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2022-06-24 23:54:18.227670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-24 23:54:18.229192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-24 23:54:18.232939: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:54:18.233938: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:54:18.234860: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:54:18.257613: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:54:18.258533: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/luqman/.local/share/virtualenvs/ME-GraphAU-NHAhuV8b/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-24 23:54:18.261953: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-06-24 23:54:18.304883: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 79ms/step
# [[463, 322, 285, 386]]
# --- 7.5797436237335205 seconds ---

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17057285364954396289
# xla_global_id: -1
# ]
# 2022-06-24 23:59:02.512062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-24 23:59:02.513791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-24 23:59:02.515608: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# # Write new file

# %%
f = open("log_crop_img.txt", "w")
f.write("All good!")
f.close()

# %% [markdown]
# # Convert video to frames

# %%
start_time = time.time()
video_path = "/nas/database/DISFA_Database/Videos_LeftCamera/LeftVideoSN010_comp.avi"
out_path = "/nas/project_data/B1_Behavior/hakim/ME-GraphAU/data/DISFA/SN010_frames"

command = "ffmpeg -i " + video_path + " " + os.path.join(out_path, "%d.png") 
os.system(command)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, avi, from '/nas/database/DISFA_Database/Videos_LeftCamera/LeftVideoSN010_comp.avi':
#   Duration: 00:04:02.20, start: 0.000000, bitrate: 9797 kb/s
#     Stream #0:0: Video: cinepak (cvid / 0x64697663), rgb24, 1024x768, 9795 kb/s, 20 fps, 20 tbr, 20 tbn, 20 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (cinepak (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/nas/project_data/B1_Behavior/hakim/ME-GraphAU/data/DISFA/SN010_frames/%d.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgb24, 1024x768, q=2-31, 200 kb/s, 20 fps, 20 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# frame= 4830 fps= 85 q=-0.0 size=N/A time=00:04:00.35 bitrate=N/A speed=4.22x
# --- 58.53860807418823 seconds ---
# frame= 4844 fps= 85 q=-0.0 Lsize=N/A time=00:04:02.20 bitrate=N/A speed=4.23x
# video:1485484kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
import pickle

# %%
box_path = '/nas/project_data/B1_Behavior/hakim/ME-GraphAU/data/DISFA/mtcnn_output/SN010.pickle'
boxes = pickle.load(open(box_path, "rb"))
print(len(boxes))
# Out:
# 4844
